# %% [markdown]
# Wybierz wszystkie wartosci z tabeli SalesLT.Customer

# %%
SELECT *
FROM SalesLT.Customer
# Out:
# (847 rows affected)
#
# CustomerID | NameStyle | Title | FirstName                | MiddleName | LastName               | Suffix | CompanyName                               | SalesPerson              | EmailAddress                                | Phone               | PasswordHash                                 | PasswordSalt | rowguid                              | ModifiedDate
# -----------+-----------+-------+--------------------------+------------+------------------------+--------+-------------------------------------------+--------------------------+---------------------------------------------+---------------------+----------------------------------------------+--------------+--------------------------------------+------------------------
# ...

# %% [markdown]
# Wybierz unikalne nazwy miast z tabeli SalesLT.Address

# %%
SELECT DISTINCT [city]
FROM SalesLT.Address
# Out:
# (269 rows affected)
#
# city
# -----------------
# Abingdon
# Albany
# Alhambra
# Alpine
# Arlington
# Auburn
# Aurora
# Austin
# Baldwin Park
# Barrie
# Barstow
# Basingstoke Hants
# Baytown
# Beaverton
# Bell Gardens
# Bellevue
# Bellingham
# Berks
# Berkshire
# Billings
# Birmingham
# Bothell
# Bountiful
# Bracknell
# Brampton
# Branch
# Branson
# Brossard
# Burnaby
# Calgary
# Camarillo
# Cambridge
# Canoga Park
# Carol Stream
# Carrollton
# Carson
# Casper
# Cedar City
# Cedar Park
# Cerritos
# Chalk Riber
# Chandler
# Chehalis
# Cheyenne
# Chicago
# Citrus Heights
# City Of Commerce
# Clackamas
# College Station
# Corpus Christi
# Culver City
# Dallas
# Daly City
# Denby
# Denver
# Detroit
# Dorval
# Downey
# Duluth
# Edina
# Edmonton
# El Cajon
# El Segundo
# Elgin
# Elk Grove
# Ellensburg
# Englewood
# Escondido
# Etobicoke
# Eureka
# Everett
# Federal Way
# Ferguson
# Fernley
# Fontana
# Fort Worth
# Fremont
# Fullerton
# Garland
# Gilbert
# Gilroy
# Gloucestershire
# ...

# %% [markdown]
# Wybierz imie, nazwisko oraz email pierwszych 10 klientow. wyswietl rezultaty jako"firstname", "lastname", "email"

# %%
SELECT TOP 10 [FirstName] as [firstname], [LastName] [lastname], [EmailAddress] [email]
FROM SalesLT.Customer
# Out:
# (10 rows affected)
#
# firstname | lastname   | email
# ----------+------------+-------------------------------
# Orlando   | Gee        | orlando0@adventure-works.com
# Keith     | Harris     | keith0@adventure-works.com
# Donna     | Carreras   | donna0@adventure-works.com
# Janet     | Gates      | janet1@adventure-works.com
# Lucy      | Harrington | lucy0@adventure-works.com
# Rosmarie  | Carroll    | rosmarie0@adventure-works.com
# Dominic   | Gash       | dominic0@adventure-works.com
# Kathleen  | Garza      | kathleen0@adventure-works.com
# Katherine | Harding    | katherine0@adventure-works.com
# Johnny    | Caprio     | johnny0@adventure-works.com
# (10 rows)
#
# Total execution time: 00:00:00.024

# %% [markdown]
# --where
